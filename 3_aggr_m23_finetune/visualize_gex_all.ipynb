# %%
import os
os.chdir("/gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune")
print(os.getcwd())
# Out:
# /gpfs/group/jin/asun/get/3_aggr_m23_finetune

# %%
import pandas as pd

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns
from gcell.utils.causal_lib import get_subnet, plot_comm, preprocess_net

from get_model.config.config import load_config
from get_model.run_region import run_zarr as run
# Out:
# /gpfs/home/asun/miniforge3/envs/get/lib/python3.12/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
# get the celltype object based on the configuration
from gcell.cell.celltype import GETHydraCellType

from get_model.config.config import load_config
from get_model.config.config import export_config, load_config_from_yaml

cfg = load_config_from_yaml("interpret_gex_finetune_config.yaml")
#celltype = 'L6 IT' # the celltype you want to load, if you have ran the predict stage multiple times on different celltypes, you can specify the celltype you want to load here
#hydra_celltype = GETHydraCellType.from_config(cfg, celltype=celltype) # if you ran the predict stage multiple times on different celltypes, you can specify the celltype you want to load here
#cd14_mono = GETHydraCellType.from_config(cfg, celltype='cd14_mono')

# %%
gene_annot_dict.values()
# Out:
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# overflow encountered in cast
# dict_values([           gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.278472
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.137679
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.011866
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.546405
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.077847
# ...              ...        ...        ...        ...     ...       ...
# 19019           Caml      chr13   55622448   55623388       0  1.541335
# 19020        Camsap1       chr2   25982932   25983856       1  2.035122
# 19021        Camsap2       chr1  136345584  136346432       1  2.020089
# 19022        Camsap3       chr8    3587293    3588166       0  0.001283
# 19023         Camta1       chr4  151108128  151108992       1  2.440310
#
#             obs  accessibility
# 0      1.158315            1.0
# 1      1.992882            1.0
# 2      1.161152            1.0
# 3      1.599664            1.0
# 4      0.139066            1.0
# ...         ...            ...
# 19019  1.640907            1.0
# 19020  1.877637            1.0
# 19021  2.045762            1.0
# 19022  0.950648            1.0
# 19023  2.433644            1.0
#
# [19024 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132011
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16620          Zwint      chr10   72654456   72655280       0  2.089551
# 16621           Zxdc       chr6   90369216   90370040       0  1.414564
# 16622         Zyg11b       chr4  108300632  108301488       1  2.223785
# 16623            Zyx       chr6   42349480   42350356       0  0.783092
# 16624           Zzz3       chr3  152395808  152396704       0  2.054359
#
#             obs  accessibility
# 0      1.177037            1.0
# 1      1.633165            1.0
# 2      1.028389            1.0
# 3      1.470027            1.0
# 4      0.052368            1.0
# ...         ...            ...
# 16620  1.939471            1.0
# 16621  1.398436            1.0
# 16622  2.070713            1.0
# 16623  0.739203            1.0
# 16624  2.001934            1.0
#
# [16625 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.277162
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.141008
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.004944
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.545695
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.070445
# ...              ...        ...        ...        ...     ...       ...
# 16608          Zwint      chr10   72654456   72655280       0  2.103749
# 16609           Zxdc       chr6   90369216   90370040       0  1.425296
# 16610         Zyg11b       chr4  108300632  108301488       1  2.200841
# 16611            Zyx       chr6   42349480   42350356       0  0.799972
# 16612           Zzz3       chr3  152395808  152396704       0  2.058307
#
#             obs  accessibility
# 0      1.168172            1.0
# 1      1.847202            1.0
# 2      1.454203            1.0
# 3      1.619777            1.0
# 4      0.000000            1.0
# ...         ...            ...
# 16608  2.102592            1.0
# 16609  1.369553            1.0
# 16610  2.074275            1.0
# 16611  1.212002            1.0
# 16612  2.063977            1.0
#
# [16613 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132010
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16619          Zwint      chr10   72654456   72655280       0  2.089551
# 16620           Zxdc       chr6   90369216   90370040       0  1.414565
# 16621         Zyg11b       chr4  108300632  108301488       1  2.223786
# 16622            Zyx       chr6   42349480   42350356       0  0.783092
# 16623           Zzz3       chr3  152395808  152396704       0  2.051729
#
#             obs  accessibility
# 0      1.118974            1.0
# 1      1.984820            1.0
# 2      1.032079            1.0
# 3      1.529906            1.0
# 4      0.088891            1.0
# ...         ...            ...
# 16619  2.152955            1.0
# 16620  1.389307            1.0
# 16621  2.214302            1.0
# 16622  0.911403            1.0
# 16623  1.921713            1.0
#
# [16624 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132010
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16620          Zwint      chr10   72654456   72655280       0  2.089551
# 16621           Zxdc       chr6   90369216   90370040       0  1.414565
# 16622         Zyg11b       chr4  108300632  108301488       1  2.223786
# 16623            Zyx       chr6   42349480   42350356       0  0.783092
# 16624           Zzz3       chr3  152395808  152396704       0  2.054360
#
#             obs  accessibility
# 0      0.957282            1.0
# 1      1.956792            1.0
# 2      0.891297            1.0
# 3      1.370497            1.0
# 4      0.037377            1.0
# ...         ...            ...
# 16620  2.106934            1.0
# 16621  1.350440            1.0
# 16622  2.070510            1.0
# 16623  0.755818            1.0
# 16624  1.958973            1.0
#
# [16625 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132010
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16620          Zwint      chr10   72654456   72655280       0  2.089551
# 16621           Zxdc       chr6   90369216   90370040       0  1.414565
# 16622         Zyg11b       chr4  108300632  108301488       1  2.223786
# 16623            Zyx       chr6   42349480   42350356       0  0.783092
# 16624           Zzz3       chr3  152395808  152396704       0  2.054360
#
#             obs  accessibility
# 0      1.165114            1.0
# 1      2.005913            1.0
# 2      1.203432            1.0
# 3      1.598253            1.0
# 4      0.041858            1.0
# ...         ...            ...
# 16620  2.272319            1.0
# 16621  1.333238            1.0
# 16622  2.125083            1.0
# 16623  1.144608            1.0
# 16624  1.932235            1.0
#
# [16625 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.285948
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.110828
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.985336
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.544683
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.081094
# ...              ...        ...        ...        ...     ...       ...
# 16546          Zwint      chr10   72654456   72655280       0  2.086732
# 16547           Zxdc       chr6   90369216   90370040       0  1.418363
# 16548         Zyg11b       chr4  108300632  108301488       1  2.182266
# 16549            Zyx       chr6   42349480   42350356       0  0.764151
# 16550           Zzz3       chr3  152395808  152396704       0  2.062140
#
#             obs  accessibility
# 0      1.212910            1.0
# 1      2.011399            1.0
# 2      1.169179            1.0
# 3      1.619759            1.0
# 4      0.000000            1.0
# ...         ...            ...
# 16546  2.324052            1.0
# 16547  1.329030            1.0
# 16548  2.154417            1.0
# 16549  0.879025            1.0
# 16550  1.834113            1.0
#
# [16551 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.296636
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.143606
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.031243
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.558447
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.079321
# ...              ...        ...        ...        ...     ...       ...
# 16619          Zwint      chr10   72654456   72655280       0  2.118242
# 16620           Zxdc       chr6   90369216   90370040       0  1.434743
# 16621         Zyg11b       chr4  108300632  108301488       1  2.244750
# 16622            Zyx       chr6   42349480   42350356       0  0.806189
# 16623           Zzz3       chr3  152395808  152396704       0  2.052460
#
#             obs  accessibility
# 0      1.230994            1.0
# 1      1.860709            1.0
# 2      1.140416            1.0
# 3      1.598665            1.0
# 4      0.000000            1.0
# ...         ...            ...
# 16619  2.404865            1.0
# 16620  1.354092            1.0
# 16621  2.153338            1.0
# 16622  0.793914            1.0
# 16623  1.891551            1.0
#
# [16624 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.283856
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.124573
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.029709
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.569063
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.068390
# ...              ...        ...        ...        ...     ...       ...
# 16512          Zwint      chr10   72654456   72655280       0  2.106562
# 16513           Zxdc       chr6   90369216   90370040       0  1.436906
# 16514         Zyg11b       chr4  108300632  108301488       1  2.307055
# 16515            Zyx       chr6   42349480   42350356       0  0.829264
# 16516           Zzz3       chr3  152395808  152396704       0  2.067737
#
#             obs  accessibility
# 0      1.225103            1.0
# 1      1.883382            1.0
# 2      1.123286            1.0
# 3      1.684630            1.0
# 4      0.000000            1.0
# ...         ...            ...
# 16512  2.333758            1.0
# 16513  1.365971            1.0
# 16514  2.084531            1.0
# 16515  0.871210            1.0
# 16516  1.975810            1.0
#
# [16517 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.217471
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.128062
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.009418
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.541458
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.074761
# ...              ...        ...        ...        ...     ...       ...
# 16596          Zwint      chr10   72654456   72655280       0  2.098183
# 16597           Zxdc       chr6   90369216   90370040       0  1.412807
# 16598         Zyg11b       chr4  108300632  108301488       1  2.235243
# 16599            Zyx       chr6   42349480   42350356       0  0.779641
# 16600           Zzz3       chr3  152395808  152396704       0  2.051016
#
#             obs  accessibility
# 0      1.252435            1.0
# 1      1.667464            1.0
# 2      1.308638            1.0
# 3      1.578110            1.0
# 4      0.081307            1.0
# ...         ...            ...
# 16596  2.097432            1.0
# 16597  1.388655            1.0
# 16598  2.200040            1.0
# 16599  1.199314            1.0
# 16600  2.112872            1.0
#
# [16601 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.269066
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.128723
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.007562
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.539943
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.070509
# ...              ...        ...        ...        ...     ...       ...
# 16589          Zwint      chr10   72654456   72655280       0  2.102793
# 16590           Zxdc       chr6   90369216   90370040       0  1.411122
# 16591         Zyg11b       chr4  108300632  108301488       1  2.226348
# 16592            Zyx       chr6   42349480   42350356       0  0.800408
# 16593           Zzz3       chr3  152395808  152396704       0  2.052865
#
#             obs  accessibility
# 0      1.147061            1.0
# 1      1.846812            1.0
# 2      1.112078            1.0
# 3      1.384480            1.0
# 4      0.000000            1.0
# ...         ...            ...
# 16589  2.055801            1.0
# 16590  1.478575            1.0
# 16591  2.021288            1.0
# 16592  0.923438            1.0
# 16593  2.097675            1.0
#
# [16594 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132010
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16620          Zwint      chr10   72654456   72655280       0  2.089551
# 16621           Zxdc       chr6   90369216   90370040       0  1.414565
# 16622         Zyg11b       chr4  108300632  108301488       1  2.223786
# 16623            Zyx       chr6   42349480   42350356       0  0.783092
# 16624           Zzz3       chr3  152395808  152396704       0  2.054360
#
#             obs  accessibility
# 0      1.248948            1.0
# 1      1.800275            1.0
# 2      1.231226            1.0
# 3      1.561038            1.0
# 4      0.000000            1.0
# ...         ...            ...
# 16620  2.023761            1.0
# 16621  1.382441            1.0
# 16622  1.987589            1.0
# 16623  1.103928            1.0
# 16624  2.177398            1.0
#
# [16625 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.146489
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.098824
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.003546
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.557110
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.068586
# ...              ...        ...        ...        ...     ...       ...
# 15828          Zwint      chr10   72654456   72655280       0  2.066394
# 15829           Zxdc       chr6   90369216   90370040       0  1.539430
# 15830         Zyg11b       chr4  108300632  108301488       1  2.235553
# 15831            Zyx       chr6   42349480   42350356       0  0.882382
# 15832           Zzz3       chr3  152395808  152396704       0  2.049129
#
#             obs  accessibility
# 0      1.251847            1.0
# 1      1.781761            1.0
# 2      1.227035            1.0
# 3      1.619708            1.0
# 4      0.474706            1.0
# ...         ...            ...
# 15828  2.096771            1.0
# 15829  1.318765            1.0
# 15830  2.079187            1.0
# 15831  1.142760            1.0
# 15832  2.120251            1.0
#
# [15833 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132010
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16620          Zwint      chr10   72654456   72655280       0  2.089551
# 16621           Zxdc       chr6   90369216   90370040       0  1.414565
# 16622         Zyg11b       chr4  108300632  108301488       1  2.223786
# 16623            Zyx       chr6   42349480   42350356       0  0.783092
# 16624           Zzz3       chr3  152395808  152396704       0  2.054360
#
#             obs  accessibility
# 0      1.155284            1.0
# 1      1.998081            1.0
# 2      0.972495            1.0
# 3      1.604830            1.0
# 4      0.017006            1.0
# ...         ...            ...
# 16620  2.325795            1.0
# 16621  1.450182            1.0
# 16622  2.209133            1.0
# 16623  1.127744            1.0
# 16624  1.846628            1.0
#
# [16625 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.267617
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.132010
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.997905
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538525
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076655
# ...              ...        ...        ...        ...     ...       ...
# 16620          Zwint      chr10   72654456   72655280       0  2.089551
# 16621           Zxdc       chr6   90369216   90370040       0  1.414565
# 16622         Zyg11b       chr4  108300632  108301488       1  2.223786
# 16623            Zyx       chr6   42349480   42350356       0  0.783092
# 16624           Zzz3       chr3  152395808  152396704       0  2.054360
#
#             obs  accessibility
# 0      1.184636            1.0
# 1      1.998537            1.0
# 2      1.034089            1.0
# 3      1.573114            1.0
# 4      0.029844            1.0
# ...         ...            ...
# 16620  2.464765            1.0
# 16621  1.375902            1.0
# 16622  2.142796            1.0
# 16623  1.010617            1.0
# 16624  1.873294            1.0
#
# [16625 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.318714
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.147077
# 2      0610010K14Rik      chr11   70237376   70238288       1  1.039172
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.588002
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.070293
# ...              ...        ...        ...        ...     ...       ...
# 16552          Zwint      chr10   72654456   72655280       0  2.131102
# 16553           Zxdc       chr6   90369216   90370040       0  1.437775
# 16554         Zyg11b       chr4  108300632  108301488       1  2.325852
# 16555            Zyx       chr6   42349480   42350356       0  0.864578
# 16556           Zzz3       chr3  152395808  152396704       0  2.066661
#
#             obs  accessibility
# 0      1.282971            1.0
# 1      1.883750            1.0
# 2      1.275937            1.0
# 3      1.494242            1.0
# 4      0.116683            1.0
# ...         ...            ...
# 16552  2.062026            1.0
# 16553  1.467710            1.0
# 16554  2.146161            1.0
# 16555  0.983643            1.0
# 16556  2.121576            1.0
#
# [16557 rows x 8 columns],            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.268903
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.131016
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.996110
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538642
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076445
# ...              ...        ...        ...        ...     ...       ...
# 16610          Zwint      chr10   72654456   72655280       0  2.089498
# 16611           Zxdc       chr6   90369216   90370040       0  1.414388
# 16612         Zyg11b       chr4  108300632  108301488       1  2.223894
# 16613            Zyx       chr6   42349480   42350356       0  0.776786
# 16614           Zzz3       chr3  152395808  152396704       0  2.056747
#
#             obs  accessibility
# 0      1.156555            1.0
# 1      1.897221            1.0
# 2      1.093000            1.0
# 3      1.586365            1.0
# 4      0.065462            1.0
# ...         ...            ...
# 16610  2.362150            1.0
# 16611  1.348534            1.0
# 16612  2.121517            1.0
# 16613  0.920167            1.0
# 16614  1.832677            1.0
#
# [16615 rows x 8 columns]])

# %%
observed_df = pd.DataFrame()
predicted_df = pd.DataFrame()
gene_annot_dict = {}

celltype_for_modeling = ['L6 IT',
                         'Astro',
                         'Endo',
                         'L5 ET',
                         'L5 IT',
                         'L6 CT',
                         'L6b',
                         'Lamp5',
                         'Meis2',
                         'Micro-PVM',
                         'OPC',
                         'Oligo',
                         'Peri',
                         'Pvalb',
                         'Sst',
                         'VLMC',
                         'Vip']

# Load all cell types
for celltype in celltype_for_modeling:
    try:
        cfg.dataset.leave_out_celltypes = celltype
        hydra_celltype = GETHydraCellType.from_config(cfg, celltype=celltype)
        gene_annot = hydra_celltype.gene_annot
        gene_annot_dict[celltype] = gene_annot
    except Exception as e:
        print(f"Error loading {celltype}: {e}")
        continue

# Intersect all gene indices to get common gene list
common_genes = set.intersection(*[set(g.index) for g in gene_annot_dict.values()])

# Extract observed/predicted into two matrices (genes x celltypes)
for celltype in celltype_for_modeling:
    df = gene_annot_dict[celltype].loc[list(common_genes)]
    observed_df[celltype] = df["obs"]
    predicted_df[celltype] = df["pred"]
# Out:
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/L6 IT.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Astro.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Endo.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/L5 ET.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/L5 IT.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/L6 CT.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/L6b.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Lamp5.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Meis2.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Micro-PVM.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/OPC.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Oligo.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Peri.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Pvalb.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Sst.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/VLMC.zarr
# Loading zarr data from /gpfs/home/asun/jin_lab/get/3_aggr_m23_finetune/output/finetune_aggr_multiome/interpret_training_from_finetune_m23_L6-IT_Astro_no_chr_split_binary_atac/Vip.zarr

# %%
df
# Out:
# overflow encountered in cast
#            gene_name Chromosome      Start        End  Strand      pred  \
# 0      0610009B22Rik      chr11   51688368   51689268       1  1.268903
# 1      0610010F05Rik      chr11   23633176   23634038       1  2.131016
# 2      0610010K14Rik      chr11   70237376   70238288       1  0.996110
# 3      0610012G03Rik      chr16   31948000   31948904       1  1.538642
# 4      0610025J13Rik       chr4   98320976   98321600       0  0.076445
# ...              ...        ...        ...        ...     ...       ...
# 15828          Vps53      chr11   76179208   76180080       1  1.703138
# 15829          Vps54      chr11   21238638   21239540       0  1.917035
# 15830          Vps72       chr3   95110648   95111552       0  1.213030
# 15831           Vps8      chr16   21422786   21423648       0  1.896468
# 15832         Vps9d1       chr8  123253776  123254656       1  1.069359
#
#             obs  accessibility
# 0      1.156555            1.0
# 1      1.897221            1.0
# 2      1.093000            1.0
# 3      1.586365            1.0
# 4      0.065462            1.0
# ...         ...            ...
# 15828  1.731369            1.0
# 15829  1.980095            1.0
# 15830  1.257245            1.0
# 15831  1.894527            1.0
# 15832  1.257245            1.0
#
# [15833 rows x 8 columns]

# %%
common_gene_list = set(gene_annot_dict['L6 IT'].index)
for celltype in celltype_for_modeling:
    try:
        common_gene_list = common_gene_list.intersection(set(gene_annot_dict[celltype].index))
    except Exception as e:
        print(f"Error loading {celltype}: {e}")
        continue
# then collect the expression
for celltype in celltype_for_modeling:
    try:
        gene_annot_dict[celltype] = gene_annot_dict[celltype].loc[np.array(common_gene_list)]
    except Exception as e:
        print(f"Error loading {celltype}: {e}")
        continue

# %%
gene_annot_dict["L6 IT"]["gene_name"].nunique()
# Out:
# 14389

# %%
dupes = df[df.duplicated("gene_name",keep=False)]
# Out:
#          gene_name Chromosome      Start        End  Strand      pred  \
# 32   1500004A13Rik       chr3   88831336   88832104       1  2.032548
# 33   1500004A13Rik       chr3   88832256   88833000       1  2.124520
# 36   1500011B03Rik       chr5  114813456  114814360       1  1.514459
# 37   1500011B03Rik       chr5  114822976  114823856       1  1.388945
# 112  1700036A12Rik       chr9   60742516   60742972       0  0.238370
#
#           obs  accessibility
# 32   1.952615            1.0
# 33   1.952615            1.0
# 36   1.607803            1.0
# 37   1.607803            1.0
# 112  0.000000            1.0
# overflow encountered in cast

# %%
len(dupes)
# Out:
# 2660

# %%
dupes['gene_name'].nunique()
# Out:
# 1216

# %%
len(common_gene_list)
# Out:
# 15833

# %%
celltype_for_modeling = ['L6 IT',
                         'L5 ET',
                         'L5 IT',
                         'L6 CT',
                         'L6b',
                         'Lamp5',
                         'Meis2',
                         'Micro-PVM',
                         'OPC',
                         'Oligo',
                         'Peri',
                         'Pvalb',
                         'Sst',
                         'VLMC',
                         'Vip']

# %%
# Extract observed/predicted into two matrices (genes x celltypes)
for celltype in celltype_for_modeling:
    df = gene_annot_dict[celltype].loc[list(common_genes)]
    observed_df[celltype] = df["obs"]
    predicted_df[celltype] = df["pred"]

# %%
# Correlation matrices
obs_corr = observed_df.corr(method='pearson')
pred_corr = predicted_df.corr(method='pearson')

# %%
len(common_genes)
# Out:
# 15833

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(1, 2, figsize=(20, 8))

sns.heatmap(obs_corr, cmap="coolwarm", annot=False, ax=axs[0])
axs[0].set_title("Observed Expression Correlation")

sns.heatmap(pred_corr, cmap="coolwarm", annot=False, ax=axs[1])
axs[1].set_title("Predicted Expression Correlation")

plt.tight_layout()
plt.show()

# %%
observed_df
# Out:
#           L6 IT     Astro      Endo     L5 ET     L5 IT     L6 CT       L6b  \
# 0      1.158315  1.177037  1.168172  1.118974  0.957282  1.165114  1.212910
# 1      1.992882  1.633165  1.847202  1.984820  1.956792  2.005913  2.011399
# 2      1.161152  1.028389  1.454203  1.032079  0.891297  1.203432  1.169179
# 3      1.599664  1.470027  1.619777  1.529906  1.370497  1.598253  1.619759
# 4      0.139066  0.052368  0.000000  0.088891  0.037377  0.041858  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 15828  1.188544  1.355217  2.161570  1.173528  1.492792  1.542768  0.800551
# 15829  1.140894  1.326008  1.469832  1.034363  1.135035  1.203432  2.024435
# 15830  1.407090  0.922661  1.865070  1.454582  1.084157  1.083855  0.860696
# 15831  2.232107  1.395088  1.212002  2.172783  1.401775  1.426508  1.195942
# 15832  1.593439  2.133362  1.525015  1.578087  2.166913  2.169910  0.841558
#
#           Lamp5     Meis2  Micro-PVM       OPC     Oligo      Peri     Pvalb  \
# 0      1.230994  1.225103   1.252435  1.147061  1.248948  1.251847  1.155284
# 1      1.860709  1.883382   1.667464  1.846812  1.800275  1.781761  1.998081
# 2      1.140416  1.123286   1.308638  1.112078  1.231226  1.227035  0.972495
# 3      1.598665  1.684630   1.578110  1.384480  1.561038  1.619708  1.604830
# 4      0.000000  0.000000   0.081307  0.000000  0.000000  0.474706  0.017006
# ...         ...       ...        ...       ...       ...       ...       ...
# 15828  1.071866  1.177171   0.000000  0.000000  1.299695  2.096771  1.171942
# 15829  1.058560  0.000000   1.872167  2.095410  1.283964  1.318765  1.072703
# 15830  1.417628  1.268266   0.000000  1.754443  0.770429  2.079187  1.068280
# 15831  2.167936  1.039141   1.931529  1.754443  1.397501  1.142760  1.565631
# 15832  1.739407  1.083248   0.830258  0.945374  2.135515  2.120251  2.175735
#
#             Sst      VLMC       Vip
# 0      1.184636  1.282971  1.156555
# 1      1.998537  1.883750  1.897221
# 2      1.034089  1.275937  1.093000
# 3      1.573114  1.494242  1.586365
# 4      0.029844  0.116683  0.065462
# ...         ...       ...       ...
# 15828  1.190652  1.444291  1.731369
# 15829  1.085224  1.453811  1.980095
# 15830  1.176482  2.046672  1.257245
# 15831  1.527912  1.238950  1.894527
# 15832  2.250031  1.353645  1.257245
#
# [15833 rows x 17 columns]

# %%
predicted_df
# Out:
#           L6 IT     Astro      Endo     L5 ET     L5 IT     L6 CT       L6b  \
# 0      1.278472  1.267617  1.277162  1.267617  1.267617  1.267617  1.285948
# 1      2.137679  2.132011  2.141008  2.132010  2.132010  2.132010  2.110828
# 2      1.011866  0.997905  1.004944  0.997905  0.997905  0.997905  0.985336
# 3      1.546405  1.538525  1.545695  1.538525  1.538525  1.538525  1.544683
# 4      0.077847  0.076655  0.070445  0.076655  0.076655  0.076655  0.081094
# ...         ...       ...       ...       ...       ...       ...       ...
# 15828  1.232165  1.541099  1.920179  1.222892  1.541099  1.541099  0.779665
# 15829  0.841162  1.222893  1.239061  0.826305  1.222892  1.222892  2.238569
# 15830  1.472330  0.826305  1.899623  1.458901  0.826305  0.826305  0.662955
# 15831  2.105736  1.458900  1.095173  2.104111  1.458901  1.458901  1.073568
# 15832  1.772041  2.104111  1.416017  1.760188  2.104111  2.104111  1.033148
#
#           Lamp5     Meis2  Micro-PVM       OPC     Oligo      Peri     Pvalb  \
# 0      1.296636  1.283856   1.217471  1.269066  1.267617  1.146489  1.267617
# 1      2.143606  2.124573   2.128062  2.128723  2.132010  2.098824  2.132010
# 2      1.031243  1.029709   1.009418  1.007562  0.997905  1.003546  0.997905
# 3      1.558447  1.569063   1.541458  1.539943  1.538525  1.557110  1.538525
# 4      0.079321  0.068390   0.074761  0.070509  0.076655  0.068586  0.076655
# ...         ...       ...        ...       ...       ...       ...       ...
# 15828  1.246965  1.216678   0.141612  0.455637  1.541099  2.066394  1.541099
# 15829  0.866208  0.053100   1.766770  1.933509  1.222892  1.539430  1.222892
# 15830  1.493160  1.194125   0.089427  0.473207  0.826305  2.235553  0.826305
# 15831  2.110487  1.011736   1.944880  0.309637  1.458901  0.882382  1.458901
# 15832  1.782705  1.209287   0.619492  0.742926  2.104111  2.049129  2.104111
#
#             Sst      VLMC       Vip
# 0      1.267617  1.318714  1.268903
# 1      2.132010  2.147077  2.131016
# 2      0.997905  1.039172  0.996110
# 3      1.538525  1.588002  1.538642
# 4      0.076655  0.070293  0.076445
# ...         ...       ...       ...
# 15828  1.541099  1.641602  1.703138
# 15829  1.222892  0.000212  1.917035
# 15830  0.826305  0.000144  1.213030
# 15831  1.458901  1.425238  1.896468
# 15832  2.104111  1.376533  1.069359
#
# [15833 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams['figure.dpi'] = 100

# get the data
x = observed_df['L6 IT']
y = predicted_df['L6 IT']

fig, ax = plt.subplots(figsize=(4, 4))
sns.scatterplot(x=x, y=y, s=1, alpha=0.5, ax=ax)
ax.set_title('Astro with Pretrain, No Finetune')

# compute max absolute value
max_val = max(np.abs(x).max(), np.abs(y).max())

# set axis limits symmetric around 0
ax.set_xlim(-max_val * 0.05, max_val)
ax.set_ylim(-max_val * 0.05, max_val)

ax.set_xlabel('Observed Expression')
ax.set_ylabel('Predicted Expression')
ax.set_aspect('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams['figure.dpi'] = 100

# get the data
x = observed_df['Astro']
y = predicted_df['Astro']

fig, ax = plt.subplots(figsize=(4, 4))
sns.scatterplot(x=x, y=y, s=1, alpha=0.5, ax=ax)
ax.set_title('Astro with Pretrain, No Finetune')

# compute max absolute value
max_val = max(np.abs(x).max(), np.abs(y).max())

# set axis limits symmetric around 0
ax.set_xlim(-max_val * 0.05, max_val)
ax.set_ylim(-max_val * 0.05, max_val)

ax.set_xlabel('Observed Expression')
ax.set_ylabel('Predicted Expression')
ax.set_aspect('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams['figure.dpi'] = 100

# get the data
x = predicted_df['L6 IT']
y = predicted_df['Astro']

fig, ax = plt.subplots(figsize=(4, 4))
sns.scatterplot(x=x, y=y, s=1, alpha=0.5, ax=ax)
ax.set_title('Astro with Pretrain, No Finetune')

# compute max absolute value
max_val = max(np.abs(x).max(), np.abs(y).max())

# set axis limits symmetric around 0
ax.set_xlim(-max_val * 0.05, max_val)
ax.set_ylim(-max_val * 0.05, max_val)

ax.set_xlabel('Observed Expression')
ax.set_ylabel('Predicted Expression')
ax.set_aspect('equal')
plt.show()
