# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Adjust delimiter if needed (default is tab for BED)
bed = pd.read_csv("/home/alsun/get/1_methyl_pre_070725/L2_3_IT_CTX_Glut.CGN.bed", sep='\t', header=None)

# View first few lines
bed.head()

# Use seaborn for a smooth distribution
sns.histplot(bed[3], bins=50, kde=True)

# Customize plot
plt.title("Distribution of L2/3 Hypo DMR Methylation")
plt.xlabel("Methylation Fraction")
plt.ylabel("Frequency")
#plt.savefig("filename", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Adjust delimiter if needed (default is tab for BED)
bed = pd.read_csv("/home/alsun/get/1_methyl_preprocess/SAA-125-2M_L2-3.CGN-both.frac.atac.canon.filter.bed", sep='\t', header=None)

# View first few lines
bed.head()

# Use seaborn for a smooth distribution
sns.histplot(bed[3], bins=50, kde=True)

# Customize plot
plt.title("Distribution of Accessibility Scores")
plt.xlabel("Accessibility Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Adjust delimiter if needed (default is tab for BED)
bed = pd.read_csv("/home/alsun/get/1_methyl_preprocess/l2-3_it.atac.canon.bed", sep='\t', header=None)

# View first few lines
bed.head()

# Use seaborn for a smooth distribution
sns.histplot(bed[3], bins=50, kde=True)

# Customize plot
plt.title("Distribution of Accessibility Scores")
plt.xlabel("Accessibility Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Load BED file assuming it's tab-separated and has at least 3 columns: chrom, start, end
# bed = pd.read_csv("/home/alsun/get/1_methyl_pre_070725/L2_3_IT_CTX_Glut.CGN.bed", sep="\t", header=None, usecols=[1, 2], names=["start", "end"])
# bed["size"] = bed["end"] - bed["start"]
#
# # Plot histogram
# plt.hist(bed["size"], bins=50, color='steelblue', edgecolor='black')
# plt.title("Histogram of Peak Sizes")
# plt.xlabel("Peak Size (bp)")
# plt.ylabel("Frequency")
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load BED file assuming it's tab-separated and has at least 3 columns: chrom, start, end
bed = pd.read_csv("/home/alsun/get/1_methyl_pre_070725/L2_3_IT_CTX_Glut.CGN.bed", sep="\t", header=None, usecols=[1, 2], names=["start", "end"])
bed["size"] = bed["end"] - bed["start"]

bed = bed[(bed["size"] > 0) & (bed["size"] <= 250)]

# Plot histogram
plt.hist(bed["size"], bins=50, color='steelblue', edgecolor='black')
plt.xlim(0, 250)
plt.title("Distribution of DMR Sizes For L2/3")
plt.xlabel("DMR Size (bp)")
plt.ylabel("Frequency")
plt.show()

# %%
# Load BED file assuming it's tab-separated and has at least 3 columns: chrom, start, end
bed = pd.read_csv("/home/alsun/get/1_methyl_pre_070725/L2_3_IT_CTX_Glut.CGN.bed", sep="\t", header=None, usecols=[1, 2], names=["start", "end"])
bed["size"] = bed["end"] - bed["start"]

# Plot histogram
plt.hist(bed["size"], bins=50, color='steelblue', edgecolor='black')
plt.title("Distribution of DMR Sizes For L2/3")
plt.xlabel("DMR Size (bp)")
plt.ylabel("Frequency")


plt.show()

# %%
# Load BED file assuming it's tab-separated and has at least 3 columns: chrom, start, end
bed = pd.read_csv("/home/alsun/get/1_methyl_preprocess/l2-3_it.atac.bed", sep="\t", header=None, usecols=[1, 2], names=["start", "end"])
bed["size"] = bed["end"] - bed["start"]

# Plot histogram
plt.hist(bed["size"], bins=50, color='steelblue', edgecolor='black')
plt.title("Distribution of Peak Sizes For L2/3")
plt.xlabel("Peak Size (bp)")
plt.ylabel("Frequency")
plt.show()
